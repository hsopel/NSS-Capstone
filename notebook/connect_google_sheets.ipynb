# %%
import geopandas as gpd
import pandas as pd
import gspread
from oauth2client.service_account import ServiceAccountCredentials
from df2gspread import df2gspread as d2g

# %%
wind = gpd.read_file('../data/USWTDB/uswtdb_v3_2_20201014.geojson')

# %%
scope = ['https://spreadsheets.google.com/feeds',
 'https://www.googleapis.com/auth/drive']
credentials = ServiceAccountCredentials.from_json_keyfile_name(
 'wind-energy-299318-3149f6f4b059.json', scopes=scope)
gc = gspread.authorize(credentials)
spreadsheet_key='1X2eaA74NfKkH-z6T2FRJMZIhSwkY1-cVXQrO37mnQEk'

# %%
lcoe = pd.read_csv('../data/levelized-cost-of-energy.csv')

# %%
lcoe_US = lcoe[lcoe['Code'] == 'USA']

# %%
lcoe_US = lcoe_US.iloc[:,0:5]

# %%
lcoe_US
# Out:
#             Entity Code  Year  Onshore wind LCOE (2019 USD/kWh)  \
# 346  United States  USA  1984                             0.297
# 347  United States  USA  1985                             0.280
# 348  United States  USA  1986                             0.253
# 349  United States  USA  1987                             0.247
# 350  United States  USA  1988                             0.190
# 351  United States  USA  1989                             0.177
# 352  United States  USA  1990                             0.196
# 353  United States  USA  1991                             0.190
# 354  United States  USA  1998                             0.105
# 355  United States  USA  1999                             0.100
# 356  United States  USA  2000                             0.088
# 357  United States  USA  2001                             0.084
# 358  United States  USA  2002                             0.080
# 359  United States  USA  2003                             0.071
# ...

# %%
wks_name= 'lcoe_USA'
d2g.upload(lcoe_US, spreadsheet_key, wks_name, credentials=credentials, row_names=True)
print('Data upload success')
# Out:
# Data upload success

# %%
lcoe_US.to_csv('lcoe_US.csv')
